# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data.

# %%
# Import dependecies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import gmaps
import requests

# Import the API key.
from config import gkey
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=gkey)

# Import the API Key
from config import weather_api_key

# Import the time and datetime module from the datetime library.
import requests
import time 
from datetime import datetime

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Step 3.Create a set of 2000 random latitudes and longitudes combinations.
lats = np.random.uniform(low = -90.000, high=90.000, size=2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Step 4. Get the nearest city using the citipy module
# Create a list for holding the cities.
cities=[]
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the cities is unique then will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
city_weather
# Out:
# {'coord': {'lon': -111.7321, 'lat': 40.0444},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 33.06,
#   'feels_like': 29.3,
#   'temp_min': 19.47,
#   'temp_max': 45.27,
#   'pressure': 1026,
#   'humidity': 49},
#  'visibility': 10000,
#  'wind': {'speed': 4, 'deg': 135, 'gust': 7},
#  'clouds': {'all': 0},
#  'dt': 1644815843,
#  'sys': {'type': 2,
#   'id': 2036804,
#   'country': 'US',
#   'sunrise': 1644762145,
#   'sunset': 1644800404},
#  'timezone': -25200,
#  'id': 5779548,
#  'name': 'Payson',
#  'cod': 200}

# %%
# Step 5. Perform an API call
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging 
print("Beginning Data Retrieval")
print("------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve the data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the data to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_date

        # Append the city information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat":city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date
                        })
    except:
        print ("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("   Data Retrieval Complete   ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | marzuq
# Processing Record 3 of Set 1 | berezovyy
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | la ronge
# Processing Record 6 of Set 1 | ituni
# City not found. Skipping...
# Processing Record 7 of Set 1 | qaanaaq
# Processing Record 8 of Set 1 | roma
# Processing Record 9 of Set 1 | mar del plata
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | eyl
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | alofi
# Processing Record 15 of Set 1 | mahon
# Processing Record 16 of Set 1 | faanui
# Processing Record 17 of Set 1 | mandalgovi
# Processing Record 18 of Set 1 | ojinaga
# Processing Record 19 of Set 1 | iqaluit
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | blonduos
# City not found. Skipping...
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | mount isa
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | villamontes
# Processing Record 26 of Set 1 | nome
# Processing Record 27 of Set 1 | narsaq
# Processing Record 28 of Set 1 | santa marta
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | yar-sale
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | provideniya
# Processing Record 35 of Set 1 | luderitz
# Processing Record 36 of Set 1 | bengkulu
# Processing Record 37 of Set 1 | asau
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | makat
# Processing Record 41 of Set 1 | qandahar
# City not found. Skipping...
# Processing Record 42 of Set 1 | vaitape
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 46 of Set 1 | saskylakh
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | lebu
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | dingle
# Processing Record 1 of Set 2 | geraldton
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | tateyama
# Processing Record 4 of Set 2 | fort nelson
# Processing Record 5 of Set 2 | estacion coahuila
# Processing Record 6 of Set 2 | erzin
# Processing Record 7 of Set 2 | guymon
# Processing Record 8 of Set 2 | meadow lake
# Processing Record 9 of Set 2 | praia da vitoria
# Processing Record 10 of Set 2 | kodiak
# Processing Record 11 of Set 2 | cidreira
# Processing Record 12 of Set 2 | namibe
# Processing Record 13 of Set 2 | victoria
# Processing Record 14 of Set 2 | groningen
# Processing Record 15 of Set 2 | kiruna
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | isangel
# Processing Record 18 of Set 2 | porto novo
# Processing Record 19 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 2 | karhal
# Processing Record 21 of Set 2 | longyearbyen
# Processing Record 22 of Set 2 | gornyak
# Processing Record 23 of Set 2 | pevek
# Processing Record 24 of Set 2 | kalmunai
# Processing Record 25 of Set 2 | hirara
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | mitsamiouli
# Processing Record 28 of Set 2 | sile
# Processing Record 29 of Set 2 | palmer
# Processing Record 30 of Set 2 | luoyang
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | alice springs
# Processing Record 33 of Set 2 | ponta do sol
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | kruisfontein
# Processing Record 36 of Set 2 | ketchikan
# Processing Record 37 of Set 2 | kirishi
# Processing Record 38 of Set 2 | atuona
# Processing Record 39 of Set 2 | ushuaia
# Processing Record 40 of Set 2 | inhambane
# Processing Record 41 of Set 2 | georgetown
# Processing Record 42 of Set 2 | egvekinot
# Processing Record 43 of Set 2 | tabas
# Processing Record 44 of Set 2 | jamestown
# Processing Record 45 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 2 | whitehorse
# Processing Record 47 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 2 | alamogordo
# Processing Record 49 of Set 2 | sao miguel do araguaia
# Processing Record 50 of Set 2 | yulara
# Processing Record 1 of Set 3 | ballina
# Processing Record 2 of Set 3 | palencia
# Processing Record 3 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 3 | constitucion
# Processing Record 5 of Set 3 | lahat
# Processing Record 6 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 3 | cayenne
# Processing Record 8 of Set 3 | cherskiy
# Processing Record 9 of Set 3 | souillac
# Processing Record 10 of Set 3 | clyde river
# Processing Record 11 of Set 3 | yinchuan
# Processing Record 12 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 3 | morant bay
# Processing Record 16 of Set 3 | calabozo
# Processing Record 17 of Set 3 | vaini
# Processing Record 18 of Set 3 | creel
# Processing Record 19 of Set 3 | rawson
# Processing Record 20 of Set 3 | dikson
# Processing Record 21 of Set 3 | lakes entrance
# Processing Record 22 of Set 3 | bay-khaak
# Processing Record 23 of Set 3 | gornopravdinsk
# Processing Record 24 of Set 3 | taltal
# Processing Record 25 of Set 3 | rosetta
# Processing Record 26 of Set 3 | gwadar
# Processing Record 27 of Set 3 | lasa
# Processing Record 28 of Set 3 | kaitangata
# Processing Record 29 of Set 3 | bluff
# Processing Record 30 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 3 | tura
# Processing Record 32 of Set 3 | airai
# Processing Record 33 of Set 3 | ulladulla
# Processing Record 34 of Set 3 | arman
# Processing Record 35 of Set 3 | ust-kut
# Processing Record 36 of Set 3 | kushiro
# Processing Record 37 of Set 3 | yazd
# Processing Record 38 of Set 3 | leningradskiy
# Processing Record 39 of Set 3 | flagstaff
# Processing Record 40 of Set 3 | sokolovyy
# Processing Record 41 of Set 3 | neiafu
# Processing Record 42 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 43 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 3 | taoudenni
# Processing Record 45 of Set 3 | upernavik
# Processing Record 46 of Set 3 | lehola
# Processing Record 47 of Set 3 | san jose
# Processing Record 48 of Set 3 | kavieng
# Processing Record 49 of Set 3 | severo-kurilsk
# Processing Record 50 of Set 3 | chuy
# Processing Record 1 of Set 4 | ilulissat
# Processing Record 2 of Set 4 | mahebourg
# Processing Record 3 of Set 4 | khatanga
# Processing Record 4 of Set 4 | narwar
# Processing Record 5 of Set 4 | itoman
# Processing Record 6 of Set 4 | shingu
# Processing Record 7 of Set 4 | bredasdorp
# Processing Record 8 of Set 4 | balkanabat
# Processing Record 9 of Set 4 | atar
# Processing Record 10 of Set 4 | tougue
# Processing Record 11 of Set 4 | klyuchi
# Processing Record 12 of Set 4 | lagoa
# Processing Record 13 of Set 4 | coihaique
# Processing Record 14 of Set 4 | san patricio
# Processing Record 15 of Set 4 | brooks
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | carnarvon
# Processing Record 18 of Set 4 | aleppo
# Processing Record 19 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 4 | torbay
# Processing Record 21 of Set 4 | vila velha
# Processing Record 22 of Set 4 | merritt
# Processing Record 23 of Set 4 | igurubi
# Processing Record 24 of Set 4 | kisesa
# Processing Record 25 of Set 4 | boa vista
# Processing Record 26 of Set 4 | nikolskoye
# Processing Record 27 of Set 4 | sao filipe
# Processing Record 28 of Set 4 | talnakh
# Processing Record 29 of Set 4 | plettenberg bay
# Processing Record 30 of Set 4 | bitung
# Processing Record 31 of Set 4 | sehithwa
# Processing Record 32 of Set 4 | yarmouth
# Processing Record 33 of Set 4 | vardo
# Processing Record 34 of Set 4 | mayo
# Processing Record 35 of Set 4 | sandviken
# Processing Record 36 of Set 4 | santa marinella
# Processing Record 37 of Set 4 | malegaon
# Processing Record 38 of Set 4 | richards bay
# Processing Record 39 of Set 4 | bambanglipuro
# Processing Record 40 of Set 4 | tual
# Processing Record 41 of Set 4 | tacna
# Processing Record 42 of Set 4 | falam
# Processing Record 43 of Set 4 | dzerzhinsk
# Processing Record 44 of Set 4 | santa cruz del sur
# Processing Record 45 of Set 4 | victor harbor
# Processing Record 46 of Set 4 | nuuk
# Processing Record 47 of Set 4 | nea apollonia
# Processing Record 48 of Set 4 | bhimavaram
# Processing Record 49 of Set 4 | ust-kulom
# Processing Record 50 of Set 4 | lons
# Processing Record 1 of Set 5 | ambon
# Processing Record 2 of Set 5 | tiksi
# Processing Record 3 of Set 5 | aksarka
# Processing Record 4 of Set 5 | porto san giorgio
# Processing Record 5 of Set 5 | thompson
# Processing Record 6 of Set 5 | touros
# Processing Record 7 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 5 | barrow
# Processing Record 9 of Set 5 | sandpoint
# Processing Record 10 of Set 5 | zhumadian
# Processing Record 11 of Set 5 | srednekolymsk
# Processing Record 12 of Set 5 | chiungutwa
# Processing Record 13 of Set 5 | high level
# Processing Record 14 of Set 5 | north platte
# Processing Record 15 of Set 5 | shchelyayur
# City not found. Skipping...
# Processing Record 16 of Set 5 | sistranda
# Processing Record 17 of Set 5 | nizhniy odes
# Processing Record 18 of Set 5 | port elizabeth
# Processing Record 19 of Set 5 | lufilufi
# Processing Record 20 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 5 | toamasina
# Processing Record 22 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 5 | port lincoln
# Processing Record 24 of Set 5 | esperance
# Processing Record 25 of Set 5 | broken hill
# Processing Record 26 of Set 5 | hirna
# Processing Record 27 of Set 5 | puerto ayora
# Processing Record 28 of Set 5 | mandalgarh
# Processing Record 29 of Set 5 | akdepe
# Processing Record 30 of Set 5 | ursulo galvan
# Processing Record 31 of Set 5 | arraial do cabo
# Processing Record 32 of Set 5 | gigmoto
# Processing Record 33 of Set 5 | meulaboh
# Processing Record 34 of Set 5 | shepsi
# Processing Record 35 of Set 5 | matara
# Processing Record 36 of Set 5 | masallatah
# Processing Record 37 of Set 5 | kaoma
# Processing Record 38 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 5 | kushmurun
# Processing Record 40 of Set 5 | palana
# Processing Record 41 of Set 5 | zomin
# Processing Record 42 of Set 5 | kahului
# Processing Record 43 of Set 5 | alibag
# Processing Record 44 of Set 5 | hay river
# Processing Record 45 of Set 5 | playa del carmen
# Processing Record 46 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 5 | new norfolk
# Processing Record 48 of Set 5 | cabo san lucas
# Processing Record 49 of Set 5 | corner brook
# Processing Record 50 of Set 5 | corumba
# Processing Record 1 of Set 6 | yenagoa
# Processing Record 2 of Set 6 | havoysund
# Processing Record 3 of Set 6 | san joaquin
# Processing Record 4 of Set 6 | belmonte
# Processing Record 5 of Set 6 | onguday
# Processing Record 6 of Set 6 | hauterive
# Processing Record 7 of Set 6 | kathmandu
# Processing Record 8 of Set 6 | agadir
# Processing Record 9 of Set 6 | caravelas
# Processing Record 10 of Set 6 | orange cove
# Processing Record 11 of Set 6 | comodoro rivadavia
# Processing Record 12 of Set 6 | turukhansk
# Processing Record 13 of Set 6 | sabha
# Processing Record 14 of Set 6 | moengo
# Processing Record 15 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 6 | port blair
# Processing Record 17 of Set 6 | san cristobal
# Processing Record 18 of Set 6 | novichikha
# Processing Record 19 of Set 6 | seddon
# Processing Record 20 of Set 6 | husavik
# Processing Record 21 of Set 6 | the valley
# Processing Record 22 of Set 6 | lamar
# Processing Record 23 of Set 6 | guangyuan
# Processing Record 24 of Set 6 | ola
# Processing Record 25 of Set 6 | alappuzha
# Processing Record 26 of Set 6 | dzhebariki-khaya
# Processing Record 27 of Set 6 | port hedland
# Processing Record 28 of Set 6 | kirakira
# Processing Record 29 of Set 6 | kupang
# Processing Record 30 of Set 6 | namatanai
# Processing Record 31 of Set 6 | salym
# Processing Record 32 of Set 6 | kaabong
# Processing Record 33 of Set 6 | oranjemund
# Processing Record 34 of Set 6 | frederico westphalen
# Processing Record 35 of Set 6 | quetame
# Processing Record 36 of Set 6 | bandarbeyla
# Processing Record 37 of Set 6 | krizevci
# Processing Record 38 of Set 6 | mogadishu
# Processing Record 39 of Set 6 | sur
# Processing Record 40 of Set 6 | flinders
# Processing Record 41 of Set 6 | halifax
# Processing Record 42 of Set 6 | sorland
# Processing Record 43 of Set 6 | bathsheba
# Processing Record 44 of Set 6 | broome
# Processing Record 45 of Set 6 | mul
# Processing Record 46 of Set 6 | reserva
# Processing Record 47 of Set 6 | amapa
# Processing Record 48 of Set 6 | grand haven
# Processing Record 49 of Set 6 | lyuban
# Processing Record 50 of Set 6 | lata
# Processing Record 1 of Set 7 | mouzakion
# City not found. Skipping...
# Processing Record 2 of Set 7 | inuvik
# Processing Record 3 of Set 7 | saint george
# Processing Record 4 of Set 7 | manica
# Processing Record 5 of Set 7 | canutama
# Processing Record 6 of Set 7 | ostrovnoy
# Processing Record 7 of Set 7 | akyab
# Processing Record 8 of Set 7 | beidao
# Processing Record 9 of Set 7 | lokosovo
# Processing Record 10 of Set 7 | honiara
# Processing Record 11 of Set 7 | pisco
# Processing Record 12 of Set 7 | banyo
# Processing Record 13 of Set 7 | mayumba
# Processing Record 14 of Set 7 | gwanda
# Processing Record 15 of Set 7 | kunyang
# Processing Record 16 of Set 7 | ewa beach
# Processing Record 17 of Set 7 | caernarfon
# Processing Record 18 of Set 7 | tambopata
# Processing Record 19 of Set 7 | slave lake
# Processing Record 20 of Set 7 | necochea
# Processing Record 21 of Set 7 | chokurdakh
# Processing Record 22 of Set 7 | waukesha
# Processing Record 23 of Set 7 | bilibino
# Processing Record 24 of Set 7 | iquitos
# Processing Record 25 of Set 7 | rincon
# Processing Record 26 of Set 7 | itarema
# Processing Record 27 of Set 7 | lorengau
# Processing Record 28 of Set 7 | cabaiguan
# Processing Record 29 of Set 7 | celestun
# Processing Record 30 of Set 7 | san carlos de bariloche
# Processing Record 31 of Set 7 | leshukonskoye
# Processing Record 32 of Set 7 | thinadhoo
# Processing Record 33 of Set 7 | flin flon
# Processing Record 34 of Set 7 | ulundi
# Processing Record 35 of Set 7 | barra do garcas
# Processing Record 36 of Set 7 | fare
# Processing Record 37 of Set 7 | nizwa
# Processing Record 38 of Set 7 | hasaki
# Processing Record 39 of Set 7 | drayton valley
# Processing Record 40 of Set 7 | walhain
# Processing Record 41 of Set 7 | fortuna
# Processing Record 42 of Set 7 | saint-joseph
# Processing Record 43 of Set 7 | sao joao da barra
# Processing Record 44 of Set 7 | magui
# City not found. Skipping...
# Processing Record 45 of Set 7 | edd
# Processing Record 46 of Set 7 | guanica
# Processing Record 47 of Set 7 | winnemucca
# Processing Record 48 of Set 7 | luzhou
# Processing Record 49 of Set 7 | wilmington
# Processing Record 50 of Set 7 | xinzhou
# Processing Record 1 of Set 8 | araceli
# Processing Record 2 of Set 8 | ixtlahuacan del rio
# Processing Record 3 of Set 8 | fairbanks
# Processing Record 4 of Set 8 | madang
# Processing Record 5 of Set 8 | grindavik
# Processing Record 6 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 7 of Set 8 | trairi
# Processing Record 8 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 8 | austin
# Processing Record 10 of Set 8 | lodja
# Processing Record 11 of Set 8 | coquimbo
# Processing Record 12 of Set 8 | chipinge
# Processing Record 13 of Set 8 | mumbwa
# Processing Record 14 of Set 8 | luang prabang
# Processing Record 15 of Set 8 | zhigansk
# Processing Record 16 of Set 8 | ahipara
# Processing Record 17 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 18 of Set 8 | noumea
# Processing Record 19 of Set 8 | scarborough
# Processing Record 20 of Set 8 | nata
# Processing Record 21 of Set 8 | rio gallegos
# Processing Record 22 of Set 8 | bati
# Processing Record 23 of Set 8 | hami
# Processing Record 24 of Set 8 | batemans bay
# Processing Record 25 of Set 8 | grand-lahou
# Processing Record 26 of Set 8 | bam
# Processing Record 27 of Set 8 | vredendal
# Processing Record 28 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 8 | ribeira brava
# Processing Record 30 of Set 8 | persianovskiy
# Processing Record 31 of Set 8 | hualmay
# Processing Record 32 of Set 8 | linxi
# Processing Record 33 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 34 of Set 8 | yumen
# Processing Record 35 of Set 8 | trat
# Processing Record 36 of Set 8 | marsala
# Processing Record 37 of Set 8 | otukpo
# Processing Record 38 of Set 8 | westport
# Processing Record 39 of Set 8 | zhuanghe
# Processing Record 40 of Set 8 | ancud
# Processing Record 41 of Set 8 | seoul
# Processing Record 42 of Set 8 | verkhnechusovskiye gorodki
# Processing Record 43 of Set 8 | tezu
# Processing Record 44 of Set 8 | yerbogachen
# Processing Record 45 of Set 8 | todos santos
# Processing Record 46 of Set 8 | vao
# Processing Record 47 of Set 8 | morgan city
# Processing Record 48 of Set 8 | lethem
# Processing Record 49 of Set 8 | faya
# Processing Record 50 of Set 8 | saldanha
# Processing Record 1 of Set 9 | berea
# Processing Record 2 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 3 of Set 9 | hovd
# Processing Record 4 of Set 9 | norman wells
# Processing Record 5 of Set 9 | mecca
# Processing Record 6 of Set 9 | codrington
# Processing Record 7 of Set 9 | askiz
# Processing Record 8 of Set 9 | stolin
# Processing Record 9 of Set 9 | sitka
# Processing Record 10 of Set 9 | mountain brook
# Processing Record 11 of Set 9 | bali
# Processing Record 12 of Set 9 | puerto del rosario
# Processing Record 13 of Set 9 | doha
# Processing Record 14 of Set 9 | karratha
# Processing Record 15 of Set 9 | aginskoye
# Processing Record 16 of Set 9 | mokhsogollokh
# Processing Record 17 of Set 9 | laguna
# Processing Record 18 of Set 9 | chaman
# Processing Record 19 of Set 9 | peniche
# Processing Record 20 of Set 9 | ust-koksa
# Processing Record 21 of Set 9 | naspur
# Processing Record 22 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 9 | sidney
# Processing Record 24 of Set 9 | shihezi
# Processing Record 25 of Set 9 | saint-pierre
# Processing Record 26 of Set 9 | portland
# Processing Record 27 of Set 9 | makakilo city
# Processing Record 28 of Set 9 | springbok
# Processing Record 29 of Set 9 | ulaangom
# Processing Record 30 of Set 9 | jilin
# Processing Record 31 of Set 9 | freetown
# Processing Record 32 of Set 9 | aksha
# Processing Record 33 of Set 9 | paita
# Processing Record 34 of Set 9 | palkino
# Processing Record 35 of Set 9 | nanortalik
# Processing Record 36 of Set 9 | shestakovo
# Processing Record 37 of Set 9 | corrales
# Processing Record 38 of Set 9 | suntar
# Processing Record 39 of Set 9 | maun
# Processing Record 40 of Set 9 | chapais
# Processing Record 41 of Set 9 | mansa
# Processing Record 42 of Set 9 | cockburn town
# Processing Record 43 of Set 9 | thio
# Processing Record 44 of Set 9 | sinnamary
# Processing Record 45 of Set 9 | baruun-urt
# Processing Record 46 of Set 9 | naze
# Processing Record 47 of Set 9 | cajamarca
# Processing Record 48 of Set 9 | consett
# Processing Record 49 of Set 9 | lugovoy
# Processing Record 50 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 10 | yeppoon
# Processing Record 2 of Set 10 | sembe
# Processing Record 3 of Set 10 | wyndham
# Processing Record 4 of Set 10 | mount gambier
# Processing Record 5 of Set 10 | mehamn
# Processing Record 6 of Set 10 | lingyuan
# Processing Record 7 of Set 10 | moose factory
# Processing Record 8 of Set 10 | katsuura
# Processing Record 9 of Set 10 | mizan teferi
# Processing Record 10 of Set 10 | vilyuysk
# Processing Record 11 of Set 10 | poum
# Processing Record 12 of Set 10 | derzhavinsk
# Processing Record 13 of Set 10 | calderitas
# Processing Record 14 of Set 10 | hofn
# Processing Record 15 of Set 10 | eureka
# Processing Record 16 of Set 10 | ulagan
# Processing Record 17 of Set 10 | khasan
# Processing Record 18 of Set 10 | miracema do tocantins
# Processing Record 19 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 10 | kindu
# Processing Record 21 of Set 10 | arlit
# Processing Record 22 of Set 10 | avera
# Processing Record 23 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 10 | talcahuano
# Processing Record 25 of Set 10 | porbandar
# Processing Record 26 of Set 10 | vila franca do campo
# Processing Record 27 of Set 10 | partenit
# Processing Record 28 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 29 of Set 10 | verkh-usugli
# Processing Record 30 of Set 10 | pilar
# Processing Record 31 of Set 10 | bandar-e lengeh
# Processing Record 32 of Set 10 | danjiangkou
# Processing Record 33 of Set 10 | klaksvik
# Processing Record 34 of Set 10 | varnavino
# Processing Record 35 of Set 10 | champasak
# Processing Record 36 of Set 10 | krasnyy yar
# Processing Record 37 of Set 10 | pacific grove
# Processing Record 38 of Set 10 | balintore
# Processing Record 39 of Set 10 | san quintin
# Processing Record 40 of Set 10 | ust-omchug
# Processing Record 41 of Set 10 | bosaso
# Processing Record 42 of Set 10 | kushima
# Processing Record 43 of Set 10 | aboisso
# Processing Record 44 of Set 10 | severnyy
# Processing Record 45 of Set 10 | santa cruz
# Processing Record 46 of Set 10 | kamenka
# Processing Record 47 of Set 10 | inverell
# Processing Record 48 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 49 of Set 10 | jiuquan
# Processing Record 50 of Set 10 | lompoc
# Processing Record 1 of Set 11 | marystown
# Processing Record 2 of Set 11 | nosy varika
# Processing Record 3 of Set 11 | yambio
# Processing Record 4 of Set 11 | beian
# Processing Record 5 of Set 11 | kralendijk
# Processing Record 6 of Set 11 | fukue
# Processing Record 7 of Set 11 | letterkenny
# Processing Record 8 of Set 11 | salalah
# Processing Record 9 of Set 11 | newcastle
# Processing Record 10 of Set 11 | tshela
# Processing Record 11 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 12 of Set 11 | salitral
# Processing Record 13 of Set 11 | haimen
# Processing Record 14 of Set 11 | shitanjing
# Processing Record 15 of Set 11 | sapa
# Processing Record 16 of Set 11 | rondonopolis
# Processing Record 17 of Set 11 | nynashamn
# Processing Record 18 of Set 11 | vermillion
# Processing Record 19 of Set 11 | quata
# Processing Record 20 of Set 11 | petlawad
# Processing Record 21 of Set 11 | panguna
# Processing Record 22 of Set 11 | muyezerskiy
# Processing Record 23 of Set 11 | tazovskiy
# Processing Record 24 of Set 11 | padang
# Processing Record 25 of Set 11 | dubbo
# Processing Record 26 of Set 11 | aden
# Processing Record 27 of Set 11 | zhangye
# Processing Record 28 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 29 of Set 11 | matiri
# Processing Record 30 of Set 11 | gayny
# Processing Record 31 of Set 11 | palu
# Processing Record 32 of Set 11 | coromandel
# Processing Record 33 of Set 11 | tongling
# Processing Record 34 of Set 11 | tuzamapan
# Processing Record 35 of Set 11 | gat
# Processing Record 36 of Set 11 | oussouye
# Processing Record 37 of Set 11 | solginskiy
# Processing Record 38 of Set 11 | port-cartier
# Processing Record 39 of Set 11 | dicabisagan
# Processing Record 40 of Set 11 | lonar
# Processing Record 41 of Set 11 | kolpashevo
# Processing Record 42 of Set 11 | san roque
# Processing Record 43 of Set 11 | buritis
# Processing Record 44 of Set 11 | adeje
# Processing Record 45 of Set 11 | krasnoselkup
# Processing Record 46 of Set 11 | sarh
# Processing Record 47 of Set 11 | pimentel
# Processing Record 48 of Set 11 | maldonado
# Processing Record 49 of Set 11 | teya
# Processing Record 50 of Set 11 | sao felix do xingu
# Processing Record 1 of Set 12 | bongued
# Processing Record 2 of Set 12 | guiyang
# Processing Record 3 of Set 12 | tamandare
# Processing Record 4 of Set 12 | ust-tsilma
# Processing Record 5 of Set 12 | odlabari
# Processing Record 6 of Set 12 | pabrade
# Processing Record 7 of Set 12 | umkomaas
# Processing Record 8 of Set 12 | linxia
# Processing Record 9 of Set 12 | kuching
# Processing Record 10 of Set 12 | northam
# Processing Record 11 of Set 12 | langham
# Processing Record 12 of Set 12 | ati
# Processing Record 13 of Set 12 | pingliang
# Processing Record 14 of Set 12 | los llanos de aridane
# Processing Record 15 of Set 12 | suluq
# Processing Record 16 of Set 12 | okhotsk
# Processing Record 17 of Set 12 | piopio
# Processing Record 18 of Set 12 | beisfjord
# Processing Record 19 of Set 12 | lazaro cardenas
# Processing Record 20 of Set 12 | nyrob
# Processing Record 21 of Set 12 | tuatapere
# Processing Record 22 of Set 12 | youhao
# Processing Record 23 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 24 of Set 12 | summerland
# Processing Record 25 of Set 12 | jiexiu
# Processing Record 26 of Set 12 | khandbari
# Processing Record 27 of Set 12 | margate
# Processing Record 28 of Set 12 | ponta delgada
# Processing Record 29 of Set 12 | boyolangu
# Processing Record 30 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 12 | robe
# Processing Record 32 of Set 12 | cuiaba
# Processing Record 33 of Set 12 | banda aceh
# Processing Record 34 of Set 12 | kununurra
# Processing Record 35 of Set 12 | saint anthony
# Processing Record 36 of Set 12 | el alto
# Processing Record 37 of Set 12 | kudahuvadhoo
# Processing Record 38 of Set 12 | polson
# Processing Record 39 of Set 12 | tsienyane
# City not found. Skipping...
# Processing Record 40 of Set 12 | haapiti
# Processing Record 41 of Set 12 | rio grande
# Processing Record 42 of Set 12 | guliston
# Processing Record 43 of Set 12 | lubumbashi
# Processing Record 44 of Set 12 | beloha
# Processing Record 45 of Set 12 | athabasca
# Processing Record 46 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 12 | mattru
# Processing Record 48 of Set 12 | muzhi
# Processing Record 49 of Set 12 | jinka
# Processing Record 50 of Set 12 | ratisbon
# City not found. Skipping...
# Processing Record 1 of Set 13 | carmelo
# Processing Record 2 of Set 13 | mahibadhoo
# Processing Record 3 of Set 13 | bambous virieux
# Processing Record 4 of Set 13 | biloela
# Processing Record 5 of Set 13 | nara
# Processing Record 6 of Set 13 | jaffna
# Processing Record 7 of Set 13 | tuy hoa
# Processing Record 8 of Set 13 | maralal
# Processing Record 9 of Set 13 | vinstra
# Processing Record 10 of Set 13 | brae
# Processing Record 11 of Set 13 | dawlatabad
# Processing Record 12 of Set 13 | tessalit
# Processing Record 13 of Set 13 | vostok
# Processing Record 14 of Set 13 | harnosand
# Processing Record 15 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 16 of Set 13 | pinawa
# Processing Record 17 of Set 13 | buraydah
# Processing Record 18 of Set 13 | dalvik
# Processing Record 19 of Set 13 | knysna
# Processing Record 20 of Set 13 | morondava
# Processing Record 21 of Set 13 | calama
# Processing Record 22 of Set 13 | russell
# Processing Record 23 of Set 13 | argayash
# Processing Record 24 of Set 13 | atbasar
# Processing Record 25 of Set 13 | porto santo
# Processing Record 26 of Set 13 | puerto ayacucho
# Processing Record 27 of Set 13 | chimore
# Processing Record 28 of Set 13 | prabumulih
# Processing Record 29 of Set 13 | liverpool
# Processing Record 30 of Set 13 | verkhnyaya inta
# Processing Record 31 of Set 13 | launceston
# Processing Record 32 of Set 13 | buluang
# Processing Record 33 of Set 13 | nchelenge
# Processing Record 34 of Set 13 | kumluca
# Processing Record 35 of Set 13 | roebourne
# Processing Record 36 of Set 13 | mnogovershinnyy
# Processing Record 37 of Set 13 | la ligua
# Processing Record 38 of Set 13 | pokaran
# Processing Record 39 of Set 13 | mangan
# Processing Record 40 of Set 13 | tandil
# Processing Record 41 of Set 13 | ulaanbaatar
# Processing Record 42 of Set 13 | sao luiz gonzaga
# Processing Record 43 of Set 13 | salinopolis
# Processing Record 44 of Set 13 | cape canaveral
# Processing Record 45 of Set 13 | berlevag
# Processing Record 46 of Set 13 | sungairaya
# Processing Record 47 of Set 13 | shkotovo-26
# City not found. Skipping...
# Processing Record 48 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 13 | pangnirtung
# Processing Record 50 of Set 13 | aberdeen
# Processing Record 1 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 14 | nador
# Processing Record 3 of Set 14 | paamiut
# Processing Record 4 of Set 14 | bontang
# Processing Record 5 of Set 14 | saint-louis
# Processing Record 6 of Set 14 | tulum
# Processing Record 7 of Set 14 | gisborne
# Processing Record 8 of Set 14 | annau
# Processing Record 9 of Set 14 | beringovskiy
# Processing Record 10 of Set 14 | souris
# Processing Record 11 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 14 | amurzet
# Processing Record 13 of Set 14 | margina
# Processing Record 14 of Set 14 | puerto princesa
# Processing Record 15 of Set 14 | tuckahoe
# Processing Record 16 of Set 14 | tanete
# Processing Record 17 of Set 14 | rocha
# Processing Record 18 of Set 14 | safwah
# City not found. Skipping...
# Processing Record 19 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 14 | rudsar
# Processing Record 22 of Set 14 | sol-iletsk
# Processing Record 23 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 14 | biga
# Processing Record 25 of Set 14 | trincomalee
# Processing Record 26 of Set 14 | cervo
# Processing Record 27 of Set 14 | creston
# Processing Record 28 of Set 14 | saint-pascal
# City not found. Skipping...
# Processing Record 29 of Set 14 | bara
# Processing Record 30 of Set 14 | riyadh
# Processing Record 31 of Set 14 | hatfield
# Processing Record 32 of Set 14 | punta alta
# Processing Record 33 of Set 14 | piro
# Processing Record 34 of Set 14 | ternate
# Processing Record 35 of Set 14 | muzaffarabad
# Processing Record 36 of Set 14 | qarqin
# Processing Record 37 of Set 14 | morro bay
# Processing Record 38 of Set 14 | gravdal
# Processing Record 39 of Set 14 | hakkari
# Processing Record 40 of Set 14 | sampit
# Processing Record 41 of Set 14 | kingsville
# Processing Record 42 of Set 14 | teluk nibung
# Processing Record 43 of Set 14 | amahai
# Processing Record 44 of Set 14 | aranos
# Processing Record 45 of Set 14 | veroce
# Processing Record 46 of Set 14 | neuquen
# Processing Record 47 of Set 14 | san pedro
# Processing Record 48 of Set 14 | valparaiso
# Processing Record 49 of Set 14 | baft
# Processing Record 50 of Set 14 | samarai
# Processing Record 1 of Set 15 | port hardy
# Processing Record 2 of Set 15 | bogashevo
# Processing Record 3 of Set 15 | wajima
# Processing Record 4 of Set 15 | semily
# Processing Record 5 of Set 15 | chumphon
# Processing Record 6 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 15 | finnsnes
# Processing Record 8 of Set 15 | cairns
# Processing Record 9 of Set 15 | santa isabel
# Processing Record 10 of Set 15 | auki
# Processing Record 11 of Set 15 | podosinovets
# Processing Record 12 of Set 15 | nagapattinam
# Processing Record 13 of Set 15 | colares
# Processing Record 14 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 15 | lebanon
# Processing Record 16 of Set 15 | okato
# Processing Record 17 of Set 15 | pedana
# Processing Record 18 of Set 15 | la brea
# Processing Record 19 of Set 15 | kabale
# Processing Record 20 of Set 15 | monrovia
# Processing Record 21 of Set 15 | iquique
# Processing Record 22 of Set 15 | stornoway
# Processing Record 23 of Set 15 | pella
# Processing Record 24 of Set 15 | tarbagatay
# Processing Record 25 of Set 15 | sakakah
# Processing Record 26 of Set 15 | tocopilla
# Processing Record 27 of Set 15 | yining
# Processing Record 28 of Set 15 | keffi
# Processing Record 29 of Set 15 | orichi
# Processing Record 30 of Set 15 | maningrida
# Processing Record 31 of Set 15 | petauke
# Processing Record 32 of Set 15 | kulhudhuffushi
# Processing Record 33 of Set 15 | kiomboi
# Processing Record 34 of Set 15 | muroto
# Processing Record 35 of Set 15 | basco
# Processing Record 36 of Set 15 | ziro
# Processing Record 37 of Set 15 | bubaque
# Processing Record 38 of Set 15 | isugod
# Processing Record 39 of Set 15 | zhanaozen
# Processing Record 40 of Set 15 | mujiayingzi
# Processing Record 41 of Set 15 | vila
# Processing Record 42 of Set 15 | lesosibirsk
# Processing Record 43 of Set 15 | olinda
# Processing Record 44 of Set 15 | tilichiki
# Processing Record 45 of Set 15 | pontarlier
# Processing Record 46 of Set 15 | arkhangelsk
# Processing Record 47 of Set 15 | monte alegre
# Processing Record 48 of Set 15 | daur
# Processing Record 49 of Set 15 | puerto baquerizo moreno
# Processing Record 50 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 1 of Set 16 | maniitsoq
# Processing Record 2 of Set 16 | iskateley
# Processing Record 3 of Set 16 | towada
# Processing Record 4 of Set 16 | bulaevo
# Processing Record 5 of Set 16 | den helder
# Processing Record 6 of Set 16 | saint-dizier
# Processing Record 7 of Set 16 | manavalakurichi
# Processing Record 8 of Set 16 | deputatskiy
# Processing Record 9 of Set 16 | manono
# Processing Record 10 of Set 16 | buala
# Processing Record 11 of Set 16 | nanpiao
# Processing Record 12 of Set 16 | san andres
# Processing Record 13 of Set 16 | phan rang
# City not found. Skipping...
# Processing Record 14 of Set 16 | uribia
# Processing Record 15 of Set 16 | alyangula
# Processing Record 16 of Set 16 | listvyagi
# Processing Record 17 of Set 16 | hegang
# Processing Record 18 of Set 16 | payson
# -----------------------------
#    Data Retrieval Complete
# -----------------------------

# %%
# Step 7. Add the weather data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)

# Re order column
new_column_order =  ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0    Hithadhoo      MV  2022-02-14 04:58:54  -0.6000   73.0833     82.36
# 1       Marzuq      YE  2022-02-14 04:58:55  14.4000   46.4667     59.04
# 2    Berezovyy      RU  2022-02-14 04:58:56  51.6667  135.7000     16.83
# 3       Hobart      AU  2022-02-14 04:55:23 -42.8794  147.3294     71.02
# 4     La Ronge      CA  2022-02-14 04:58:56  55.1001 -105.2842     -0.15
# ..         ...     ...                  ...      ...       ...       ...
# 703     Uribia      CO  2022-02-14 05:20:35  11.7139  -72.2660     76.41
# 704  Alyangula      AU  2022-02-14 05:20:36 -13.8483  136.4192     86.85
# 705  Listvyagi      RU  2022-02-14 05:20:37  53.6772   86.9510     19.33
# 706     Hegang      CN  2022-02-14 05:20:37  47.4000  130.3667     11.30
# 707     Payson      US  2022-02-14 05:17:23  40.0444 -111.7321     45.27
#
#      Humidity  Cloudiness  Wind Speed
# 0          72          79       12.97
# 1          41          34        3.42
# 2          85         100        3.58
# 3          65          75        9.22
# 4          78           0        5.75
# ..        ...         ...         ...
# 703        79           5       14.09
# 704        61          11       12.41
# 705        73         100        8.19
# 706        77          51        2.73
# 707        49           0        4.00
#
# [708 rows x 9 columns]

# %%
# Step 8. Export the DataFrame as a CSV file
output_data_file = "WeatherPy_Database.csv"

# Export into a CSV
city_data_df.to_csv(output_data_file, index_label="City ID")
